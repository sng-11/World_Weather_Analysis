# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 585

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "3c9bb0fa2b1219221cc5fb9ca13b73d9"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3c9bb0fa2b1219221cc5fb9ca13b73d9

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | asau
# Processing Record 2 of Set 1 | kongolo
# Processing Record 3 of Set 1 | belaya gora
# Processing Record 4 of Set 1 | leningradskiy
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | nemuro
# Processing Record 7 of Set 1 | katsuura
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | college
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | newton
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | hasaki
# Processing Record 16 of Set 1 | ambilobe
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | puyo
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | kaitangata
# ...

# %%
len(city_data)
# Out:
# 544

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Asau  46.4333   26.4000     78.28        63          98
# 1        Kongolo  -5.3833   27.0000     85.41        30          67
# 2    Belaya Gora  68.5333  146.4167     40.55        86         100
# 3  Leningradskiy  69.3833  178.4167     40.37        95          97
# 4         Kodiak  57.7900 -152.4072     60.31        77          90
# 5         Nemuro  43.3236  145.5750     68.56        96          71
# 6       Katsuura  35.1333  140.3000     80.71        87          62
# 7      Busselton -33.6500  115.3333     39.09        82           0
# 8        College  64.8569 -147.8028     75.20        56          20
# 9       Cherskiy  68.7500  161.3000     47.48        77          49
#
#    Wind Speed Country                 Date Current Description
# 0        3.49      RO  2021-08-05 19:50:05       moderate rain
# 1        2.95      CD  2021-08-05 19:50:05       broken clouds
# ...

# %%
new_column_order = ["City", "Country", "Date", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
reformatted_city_data_df = city_data_df[new_column_order]
reformatted_city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0           Asau      RO  2021-08-05 19:50:05  46.4333   26.4000     78.28
# 1        Kongolo      CD  2021-08-05 19:50:05  -5.3833   27.0000     85.41
# 2    Belaya Gora      RU  2021-08-05 19:50:05  68.5333  146.4167     40.55
# 3  Leningradskiy      RU  2021-08-05 19:50:06  69.3833  178.4167     40.37
# 4         Kodiak      US  2021-08-05 19:48:49  57.7900 -152.4072     60.31
# 5         Nemuro      JP  2021-08-05 19:50:07  43.3236  145.5750     68.56
# 6       Katsuura      JP  2021-08-05 19:50:07  35.1333  140.3000     80.71
# 7      Busselton      AU  2021-08-05 19:50:07 -33.6500  115.3333     39.09
# 8        College      US  2021-08-05 19:49:27  64.8569 -147.8028     75.20
# 9       Cherskiy      RU  2021-08-05 19:48:33  68.7500  161.3000     47.48
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        63          98        3.49       moderate rain
# ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
reformatted_city_data_df.to_csv(output_data_file, index_label="City_ID")
